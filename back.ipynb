# %%
#!/usr/bin/env python3
import os
import sys
import subprocess
import time
import difflib
import re

COMPILER_PATH = "./build/Compiler"  # 编译器路径
TESTCASE_DIR = "testcases"          # 测试用例目录
COMPARATOR = "/usr/bin/riscv64-unknown-elf-gcc" 
QEMU_PATH = "qemu-riscv64"          # RISC-V模拟器
TIMEOUT_DURATION = 2                # 运行超时阈值(秒)
COMPILE_TIMEOUT = 60                # 编译超时阈值(秒)
OUTPUT_DIR = "./output"             # 输出目录（仅用于.bin和.actual文件）

# ===== 初始化统计变量 =====
CE_list = []      # 编译错误
RE_list = []      # 运行时错误
TLE_list = []     # 超时错误
WA_list = []      # 错误答案
AC_list = []      # 通过用例
Time_Out = []     # 超时函数
Bad_test = []     # 无效测试
total_time = 0    # 总耗时

# ===== 准备输出目录 =====
os.makedirs(OUTPUT_DIR, exist_ok=True)  # 仅用于.bin和.actual文件

# ===== 收集测试用例 =====
test_list = []
for root, dirs, files in os.walk(TESTCASE_DIR):
    for file in files:
        if file.endswith(".sy"):
            test_list.append(os.path.join(root, file))

# ===== 主测试循环 =====
for test in test_list:
    base_name = os.path.basename(test).replace(".sy", "")
    base_path = os.path.dirname(test)
    out_file = os.path.join(base_path, base_name + ".out")
    in_file = os.path.join(base_path, base_name + ".in")
    # .s文件生成在.sy文件同目录下
    s_file = os.path.join(base_path, base_name + ".s")
    bin_file = os.path.join(OUTPUT_DIR, base_name + ".bin")
    actual_out = os.path.join(OUTPUT_DIR, base_name + ".actual")
    
    print(f"Processing: {test}")

    # 检查.out文件是否存在
    if not os.path.exists(out_file):
        Bad_test.append(test)
        print(f"  Bad Test: Missing .out file for {test}")
        continue

    # === 步骤1: 编译源文件生成汇编 ===
    try:
        compile_args = [COMPILER_PATH, test, "-o", s_file]
        # 添加--march选项传递给编译器（如果需要）
        # compile_args += ["--march=rv64gc"]
        subprocess.run(compile_args, timeout=COMPILE_TIMEOUT, check=True,
                       stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    except subprocess.TimeoutExpired:
        CE_list.append(test)
        Time_Out.append(test)
        print(f"  Compiler Timeout: {test}")
        continue
    except subprocess.CalledProcessError as e:
        CE_list.append(test)
        print(f"  Compiler Error: {test}\n    {e.stderr.decode().strip()}")
        continue
    
    # === 步骤2: 编译汇编生成可执行文件（使用图片中的参数）===
    try:
        # 核心修改：添加rv64gc选项（G=IMAFFD，C=压缩指令）
        assemble_args = [
            COMPARATOR, 
            "-static", 
            "-march=rv64gc",  # 使用图片中的精确参数
            "-mabi=lp64",     # 64位ABI
            s_file, 
            "-o", 
            bin_file,
            "-lm"             # 链接数学库（如果有浮点运算）
        ]
        subprocess.run(assemble_args, timeout=TIMEOUT_DURATION, check=True,
                       stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    except subprocess.TimeoutExpired:
        CE_list.append(test)
        Time_Out.append(test)
        print(f"  Assembler Timeout: {test}")
        continue
    except subprocess.CalledProcessError as e:
        # 详细输出汇编器错误信息
        error_msg = e.stderr.decode().strip()
        CE_list.append(test)
        print(f"  Assembler Error: {test}\n    {error_msg}")
        
        # 保存汇编错误日志以便调试
        asm_error_log = os.path.join(base_path, base_name + "_asm_error.log")
        with open(asm_error_log, "w") as err_file:
            err_file.write(f"Assembler command: {' '.join(assemble_args)}\n")
            err_file.write(f"Error details:\n{error_msg}\n")
        continue
    except FileNotFoundError:
        CE_list.append(test)
        print(f"  Error: Assembler not found at {COMPARATOR}")
        continue
    
    # === 步骤3: 执行测试并计时 ===
    start_time = time.time()
    try:
        # 准备输入数据
        input_data = None
        if os.path.exists(in_file):
            with open(in_file, "rb") as f:
                input_data = f.read()
        
        # 执行程序（指定64位架构）
        run_args = [QEMU_PATH, "-cpu", "rv64", bin_file]
        result = subprocess.run(run_args, input=input_data, timeout=TIMEOUT_DURATION,
                                stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        elapsed = time.time() - start_time
        total_time += elapsed
        
        # 处理输出
        output = result.stdout.decode(errors="ignore")
        if not output.endswith('\n'):
            output += '\n'
        output += str(result.returncode) + '\n'
        
        with open(actual_out, "w") as f:
            f.write(output)
    
    except subprocess.TimeoutExpired:
        TLE_list.append(test)
        Time_Out.append(test)
        total_time += TIMEOUT_DURATION
        print(f"  Timeout Error: {test}")
        continue
    except Exception as e:
        # 保存运行错误日志
        runtime_error_log = os.path.join(OUTPUT_DIR, base_name + "_runtime_error.log")
        with open(runtime_error_log, "w") as err_file:
            err_file.write(f"Runtime error: {str(e)}\n")
            if result:
                err_file.write(f"Stdout: {result.stdout.decode(errors='ignore')}\n")
                err_file.write(f"Stderr: {result.stderr.decode(errors='ignore')}\n")
                
        RE_list.append(test)
        print(f"  Runtime Error: {test}\n    {str(e)}")
        continue
    
    # === 步骤4: 兼容性更强的输出比较 ===
    try:
        with open(out_file, "r") as f:
            expected_output = f.read()
        
        # 规范化比较（允许±1误差和浮点容错）
        def normalize_output(text):
            lines = text.strip().splitlines()
            # 尝试将数值解析为浮点数，否则保持原字符串
            normalized = []
            for line in lines:
                try:
                    # 浮点数容差处理
                    val = float(line)
                    normalized.append(f"{val:.6f}")  # 限制精度
                except ValueError:
                    # 处理整数/字符串
                    normalized.append(line.strip())
            return normalized
        
        norm_output = normalize_output(output)
        norm_expected = normalize_output(expected_output)
        
        # 容错比较
        if len(norm_output) != len(norm_expected):
            WA_list.append(test)
            print(f"  Wrong Answer: Output line count mismatch")
        else:
            all_match = True
            for i, (out_line, exp_line) in enumerate(zip(norm_output, norm_expected)):
                if out_line != exp_line:
                    try:
                        # 浮点数容差比较
                        out_val = float(out_line)
                        exp_val = float(exp_line)
                        if abs(out_val - exp_val) > 1e-5:  # 万分之一误差容忍
                            all_match = False
                    except ValueError:
                        all_match = False
            
            if all_match:
                AC_list.append(test)
                print(f"  Accepted: {test} ({elapsed:.3f}s)")
            else:
                WA_list.append(test)
                print(f"  Wrong Answer: {test}")
                
                # 生成详细差异报告
                diff = difflib.unified_diff(
                    output.splitlines(), expected_output.splitlines(),
                    fromfile="Actual", tofile="Expected", lineterm=''
                )
                diff_report = os.path.join(OUTPUT_DIR, base_name + ".diff")
                with open(diff_report, "w") as df:
                    df.write("\n".join(diff))
    except Exception as e:
        WA_list.append(test)
        print(f"  Output Comparison Failed: {test}\n    {str(e)}")

# ===== 打印统计结果 =====
print("\n===== Test Summary =====")
print(f"Compiler Error: Total: {len(CE_list)}")
print(f"Runtime Error: Total: {len(RE_list)}")
print(f"Timeout Error: Total: {len(TLE_list)}")
print(f"Wrong Answer: Total: {len(WA_list)}")
print(f"TimeOut Function: {len(Time_Out)}")
print(f"Bad Test: Total: {len(Bad_test)}")
print(f"Accepted: Total: {len(AC_list)}")
print(f"TOTAL TIME: {total_time:.3f} seconds")
print("========================")

# 保存详细报告
with open(os.path.join(OUTPUT_DIR, "test_report.log"), "w") as report:
    report.write("===== Detailed Test Report =====\n")
    report.write(f"Total Test Cases: {len(test_list)}\n\n")
    report.write(f"Compiler: {COMPILER_PATH}\n")
    report.write(f"Assembler: {COMPARATOR}\n")
    report.write(f"QEMU: {QEMU_PATH}\n")
    report.write(f"Compile Options: -static -march=rv64gc -mabi=lp64\n\n")
    
    if CE_list:
        report.write("\n===== Compiler Errors =====\n")
        for test in CE_list:
            report.write(f"  {test}\n")
    
    if RE_list:
        report.write("\n===== Runtime Errors =====\n")
        for test in RE_list:
            report.write(f"  {test}\n")
    
    if TLE_list:
        report.write("\n===== Timeout Errors =====\n")
        for test in TLE_list:
            report.write(f"  {test}\n")
    
    if WA_list:
        report.write("\n===== Wrong Answers =====\n")
        for test in WA_list:
            report.write(f"  {test}\n")
    
    if Bad_test:
        report.write("\n===== Bad Tests (missing .out) =====\n")
        for test in Bad_test:
            report.write(f"  {test}\n")
    
    if AC_list:
        report.write("\n===== Accepted Tests =====\n")
        for test in AC_list:
            report.write(f"  {test}\n")
    
    report.write(f"\n===== Performance Summary =====\n")
    report.write(f"Total Execution Time: {total_time:.3f} seconds\n")
    if test_list:
        avg_time = total_time / len(AC_list) if AC_list else 0
        report.write(f"Average Time per Test: {avg_time:.4f} seconds\n")

print(f"\nDetailed report saved to: {os.path.join(OUTPUT_DIR, 'test_report.log')}")
# Out:
# Processing: testcases/h_functional/05_param_name.sy
#   Compiler Error: testcases/h_functional/05_param_name.sy
#
# Processing: testcases/h_functional/39_fp_params.sy
#   Compiler Error: testcases/h_functional/39_fp_params.sy
#
# Processing: testcases/h_functional/24_array_only.sy
#   Compiler Error: testcases/h_functional/24_array_only.sy
#
# Processing: testcases/h_functional/06_func_name.sy
#   Assembler Error: testcases/h_functional/06_func_name.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/h_functional/08_global_arr_init.sy
#   Assembler Error: testcases/h_functional/08_global_arr_init.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/h_functional/36_rotate.sy
#   Compiler Error: testcases/h_functional/36_rotate.sy
#
# Processing: testcases/h_functional/22_matrix_multiply.sy
#   Compiler Error: testcases/h_functional/22_matrix_multiply.sy
#
# Processing: testcases/h_functional/25_scope3.sy
#   Compiler Error: testcases/h_functional/25_scope3.sy
#
# Processing: testcases/h_functional/27_scope5.sy
#   Compiler Error: testcases/h_functional/27_scope5.sy
#
# Processing: testcases/h_functional/00_comment2.sy
#   Assembler Error: testcases/h_functional/00_comment2.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/h_functional/04_break_continue.sy
#   Compiler Error: testcases/h_functional/04_break_continue.sy
#
# Processing: testcases/h_functional/01_multiple_returns.sy
#   Assembler Error: testcases/h_functional/01_multiple_returns.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/h_functional/30_many_dimensions.sy
#   Compiler Error: testcases/h_functional/30_many_dimensions.sy
#
# Processing: testcases/h_functional/17_maximal_clique.sy
#   Compiler Error: testcases/h_functional/17_maximal_clique.sy
#
# Processing: testcases/h_functional/31_many_indirections.sy
#   Compiler Error: testcases/h_functional/31_many_indirections.sy
#
# Processing: testcases/h_functional/11_BST.sy
#   Compiler Error: testcases/h_functional/11_BST.sy
#
# Processing: testcases/h_functional/15_graph_coloring.sy
#   Compiler Error: testcases/h_functional/15_graph_coloring.sy
#
# Processing: testcases/h_functional/26_scope4.sy
#   Compiler Error: testcases/h_functional/26_scope4.sy
#
# Processing: testcases/h_functional/12_DSU.sy
#   Compiler Error: testcases/h_functional/12_DSU.sy
#
# Processing: testcases/h_functional/18_prim.sy
#   Compiler Error: testcases/h_functional/18_prim.sy
#
# Processing: testcases/h_functional/28_side_effect2.sy
#   Compiler Error: testcases/h_functional/28_side_effect2.sy
#
# Processing: testcases/h_functional/07_arr_init_nd.sy
#   Assembler Error: testcases/h_functional/07_arr_init_nd.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/h_functional/32_many_params3.sy
#   Compiler Error: testcases/h_functional/32_many_params3.sy
#
# Processing: testcases/h_functional/20_sort.sy
#   Compiler Error: testcases/h_functional/20_sort.sy
#
# Processing: testcases/h_functional/33_multi_branch.sy
#   Compiler Error: testcases/h_functional/33_multi_branch.sy
#
# Processing: testcases/h_functional/38_light2d.sy
#   Compiler Error: testcases/h_functional/38_light2d.sy
#
# Processing: testcases/h_functional/35_math.sy
#   Compiler Error: testcases/h_functional/35_math.sy
#
# Processing: testcases/h_functional/13_LCA.sy
#   Compiler Error: testcases/h_functional/13_LCA.sy
#
# Processing: testcases/h_functional/37_dct.sy
#   Compiler Error: testcases/h_functional/37_dct.sy
#
# Processing: testcases/h_functional/16_k_smallest.sy
#   Compiler Error: testcases/h_functional/16_k_smallest.sy
#     terminate called after throwing an instance of 'std::invalid_argument'
#   what():  stoi
# Processing: testcases/h_functional/34_multi_loop.sy
#   Compiler Error: testcases/h_functional/34_multi_loop.sy
#
# Processing: testcases/h_functional/29_long_line.sy
#   Compiler Error: testcases/h_functional/29_long_line.sy
#
# Processing: testcases/h_functional/02_ret_in_block.sy
#   Compiler Error: testcases/h_functional/02_ret_in_block.sy
#
# Processing: testcases/h_functional/03_branch.sy
#   Compiler Error: testcases/h_functional/03_branch.sy
#
# Processing: testcases/h_functional/19_search.sy
#   Compiler Error: testcases/h_functional/19_search.sy
#
# Processing: testcases/h_functional/23_json.sy
#   Compiler Error: testcases/h_functional/23_json.sy
#
# Processing: testcases/h_functional/14_dp.sy
#   Compiler Error: testcases/h_functional/14_dp.sy
#
# Processing: testcases/h_functional/21_union_find.sy
#   Compiler Error: testcases/h_functional/21_union_find.sy
#     terminate called after throwing an instance of 'std::invalid_argument'
#   what():  stoi
# Processing: testcases/h_functional/09_BFS.sy
#   Compiler Error: testcases/h_functional/09_BFS.sy
#
# Processing: testcases/h_functional/10_DFS.sy
#   Compiler Error: testcases/h_functional/10_DFS.sy
#
# Processing: testcases/functional/76_n_queens.sy
#   Compiler Error: testcases/functional/76_n_queens.sy
#
# Processing: testcases/functional/71_full_conn.sy
#   Compiler Error: testcases/functional/71_full_conn.sy
#
# Processing: testcases/functional/80_chaos_token.sy
#   Compiler Error: testcases/functional/80_chaos_token.sy
#
# Processing: testcases/functional/59_sort_test5.sy
#   Compiler Error: testcases/functional/59_sort_test5.sy
#
# Processing: testcases/functional/27_while_test2.sy
#   Compiler Error: testcases/functional/27_while_test2.sy
#
# Processing: testcases/functional/93_nested_calls.sy
#   Compiler Error: testcases/functional/93_nested_calls.sy
#
# Processing: testcases/functional/21_if_test2.sy
#   Compiler Error: testcases/functional/21_if_test2.sy
#
# Processing: testcases/functional/10_var_defn_func.sy
#   Assembler Error: testcases/functional/10_var_defn_func.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/functional/48_assign_complex_expr.sy
#   Compiler Error: testcases/functional/48_assign_complex_expr.sy
#
# Processing: testcases/functional/81_skip_spaces.sy
#   Compiler Error: testcases/functional/81_skip_spaces.sy
#
# Processing: testcases/functional/41_unary_op2.sy
#   Compiler Error: testcases/functional/41_unary_op2.sy
#
# Processing: testcases/functional/96_matrix_add.sy
#   Compiler Error: testcases/functional/96_matrix_add.sy
#
# Processing: testcases/functional/88_many_params2.sy
#   Compiler Error: testcases/functional/88_many_params2.sy
#
# Processing: testcases/functional/90_many_locals.sy
#   Compiler Error: testcases/functional/90_many_locals.sy
#     terminate called after throwing an instance of 'std::invalid_argument'
#   what():  stoi
# Processing: testcases/functional/45_comment1.sy
#   Assembler Error: testcases/functional/45_comment1.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/functional/23_if_test4.sy
#   Compiler Error: testcases/functional/23_if_test4.sy
#
# Processing: testcases/functional/37_op_priority3.sy
#   Compiler Error: testcases/functional/37_op_priority3.sy
#
# Processing: testcases/functional/86_long_code2.sy
#   Compiler Error: testcases/functional/86_long_code2.sy
#
# Processing: testcases/functional/87_many_params.sy
#   Compiler Error: testcases/functional/87_many_params.sy
#
# Processing: testcases/functional/84_long_array2.sy
#   Compiler Error: testcases/functional/84_long_array2.sy
#
# Processing: testcases/functional/66_exgcd.sy
#   Compiler Error: testcases/functional/66_exgcd.sy
#
# Processing: testcases/functional/13_sub2.sy
#   Compiler Error: testcases/functional/13_sub2.sy
#
# Processing: testcases/functional/46_hex_defn.sy
#   Assembler Error: testcases/functional/46_hex_defn.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/functional/58_sort_test4.sy
#   Compiler Error: testcases/functional/58_sort_test4.sy
#
# Processing: testcases/functional/05_arr_defn4.sy
#   Compiler Error: testcases/functional/05_arr_defn4.sy
#
# Processing: testcases/functional/18_divc.sy
#   Assembler Error: testcases/functional/18_divc.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/functional/43_logi_assign.sy
#   Compiler Error: testcases/functional/43_logi_assign.sy
#     Compiler: /home/dh/Compiler/Compiler/MyBackend/RISCVContext.cpp:48: void RISCVContext::extraDealStoreInst(RISCVInst*, StoreInst*): Assertion `allocInst && "must not be nullptr"' failed.
# Processing: testcases/functional/11_add2.sy
#   Assembler Error: testcases/functional/11_add2.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/functional/28_while_test3.sy
#   Compiler Error: testcases/functional/28_while_test3.sy
#
# Processing: testcases/functional/20_rem.sy
#   Compiler Error: testcases/functional/20_rem.sy
#
# Processing: testcases/functional/03_arr_defn2.sy
#   Assembler Error: testcases/functional/03_arr_defn2.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/functional/51_short_circuit3.sy
#   Compiler Error: testcases/functional/51_short_circuit3.sy
#     Compiler: /home/dh/Compiler/Compiler/MyBackend/RISCVContext.cpp:48: void RISCVContext::extraDealStoreInst(RISCVInst*, StoreInst*): Assertion `allocInst && "must not be nullptr"' failed.
# Processing: testcases/functional/74_kmp.sy
#   Compiler Error: testcases/functional/74_kmp.sy
#
# Processing: testcases/functional/29_break.sy
#   Compiler Error: testcases/functional/29_break.sy
#
# Processing: testcases/functional/32_while_if_test2.sy
#   Compiler Error: testcases/functional/32_while_if_test2.sy
#
# Processing: testcases/functional/16_mulc.sy
#   Assembler Error: testcases/functional/16_mulc.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/functional/62_percolation.sy
#   Compiler Error: testcases/functional/62_percolation.sy
#
# Processing: testcases/functional/36_op_priority2.sy
#   Assembler Error: testcases/functional/36_op_priority2.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/functional/31_while_if_test1.sy
#   Compiler Error: testcases/functional/31_while_if_test1.sy
#
# Processing: testcases/functional/42_empty_stmt.sy
#   Compiler Error: testcases/functional/42_empty_stmt.sy
#
# Processing: testcases/functional/12_addc.sy
#   Assembler Error: testcases/functional/12_addc.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/functional/52_scope.sy
#   Compiler Error: testcases/functional/52_scope.sy
#
# Processing: testcases/functional/15_mul.sy
#   Assembler Error: testcases/functional/15_mul.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/functional/63_big_int_mul.sy
#   Compiler Error: testcases/functional/63_big_int_mul.sy
#     terminate called after throwing an instance of 'std::invalid_argument'
#   what():  stoi
# Processing: testcases/functional/54_hidden_var.sy
#   Compiler Error: testcases/functional/54_hidden_var.sy
#
# Processing: testcases/functional/61_sort_test7.sy
#   Compiler Error: testcases/functional/61_sort_test7.sy
#
# Processing: testcases/functional/92_register_alloc.sy
#   Compiler Error: testcases/functional/92_register_alloc.sy
#
# Processing: testcases/functional/56_sort_test2.sy
#   Compiler Error: testcases/functional/56_sort_test2.sy
#
# Processing: testcases/functional/60_sort_test6.sy
#   Compiler Error: testcases/functional/60_sort_test6.sy
#
# Processing: testcases/functional/79_var_name.sy
#   Compiler Error: testcases/functional/79_var_name.sy
#
# Processing: testcases/functional/98_matrix_mul.sy
#   Compiler Error: testcases/functional/98_matrix_mul.sy
#
# Processing: testcases/functional/07_const_var_defn3.sy
#   Assembler Error: testcases/functional/07_const_var_defn3.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/functional/09_func_defn.sy
#   Compiler Error: testcases/functional/09_func_defn.sy
#
# Processing: testcases/functional/85_long_code.sy
#   Compiler Error: testcases/functional/85_long_code.sy
#
# Processing: testcases/functional/70_dijkstra.sy
#   Compiler Error: testcases/functional/70_dijkstra.sy
#
# Processing: testcases/functional/02_var_defn3.sy
#   Assembler Error: testcases/functional/02_var_defn3.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/functional/40_unary_op.sy
#   Compiler Error: testcases/functional/40_unary_op.sy
#
# Processing: testcases/functional/75_max_flow.sy
#   Compiler Error: testcases/functional/75_max_flow.sy
#
# Processing: testcases/functional/01_var_defn2.sy
#   Assembler Error: testcases/functional/01_var_defn2.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/functional/00_main.sy
#   Assembler Error: testcases/functional/00_main.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/functional/08_const_array_defn.sy
#   Assembler Error: testcases/functional/08_const_array_defn.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/functional/82_long_func.sy
#   Compiler Error: testcases/functional/82_long_func.sy
#
# Processing: testcases/functional/83_long_array.sy
#   Compiler Error: testcases/functional/83_long_array.sy
#
# Processing: testcases/functional/68_brainfk.sy
#   Compiler Error: testcases/functional/68_brainfk.sy
#     terminate called after throwing an instance of 'std::invalid_argument'
#   what():  stoi
# Processing: testcases/functional/33_while_if_test3.sy
#   Compiler Error: testcases/functional/33_while_if_test3.sy
#
# Processing: testcases/functional/50_short_circuit.sy
#   Compiler Error: testcases/functional/50_short_circuit.sy
#     Compiler: /home/dh/Compiler/Compiler/MyBackend/RISCVContext.cpp:48: void RISCVContext::extraDealStoreInst(RISCVInst*, StoreInst*): Assertion `allocInst && "must not be nullptr"' failed.
# Processing: testcases/functional/94_nested_loops.sy
#   Compiler Error: testcases/functional/94_nested_loops.sy
#
# Processing: testcases/functional/25_while_if.sy
#   Compiler Error: testcases/functional/25_while_if.sy
#
# Processing: testcases/functional/30_continue.sy
#   Compiler Error: testcases/functional/30_continue.sy
#
# Processing: testcases/functional/39_op_priority5.sy
#   Assembler Error: testcases/functional/39_op_priority5.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/functional/91_many_locals2.sy
#   Compiler Error: testcases/functional/91_many_locals2.sy
#
# Processing: testcases/functional/24_if_test5.sy
#   Compiler Error: testcases/functional/24_if_test5.sy
#
# Processing: testcases/functional/49_if_complex_expr.sy
#   Compiler Error: testcases/functional/49_if_complex_expr.sy
#
# Processing: testcases/functional/89_many_globals.sy
#   Compiler Error: testcases/functional/89_many_globals.sy
#     Compiler: /home/dh/Compiler/Compiler/MyBackend/RISCVContext.cpp:48: void RISCVContext::extraDealStoreInst(RISCVInst*, StoreInst*): Assertion `allocInst && "must not be nullptr"' failed.
# Processing: testcases/functional/34_arr_expr_len.sy
#   Compiler Error: testcases/functional/34_arr_expr_len.sy
#
# Processing: testcases/functional/67_reverse_output.sy
#   Compiler Error: testcases/functional/67_reverse_output.sy
#
# Processing: testcases/functional/22_if_test3.sy
#   Compiler Error: testcases/functional/22_if_test3.sy
#
# Processing: testcases/functional/26_while_test1.sy
#   Compiler Error: testcases/functional/26_while_test1.sy
#
# Processing: testcases/functional/77_substr.sy
#   Compiler Error: testcases/functional/77_substr.sy
#
# Processing: testcases/functional/44_stmt_expr.sy
#   Compiler Error: testcases/functional/44_stmt_expr.sy
#     Compiler: /home/dh/Compiler/Compiler/MyBackend/RISCVContext.cpp:48: void RISCVContext::extraDealStoreInst(RISCVInst*, StoreInst*): Assertion `allocInst && "must not be nullptr"' failed.
# Processing: testcases/functional/14_subc.sy
#   Compiler Error: testcases/functional/14_subc.sy
#
# Processing: testcases/functional/17_div.sy
#   Assembler Error: testcases/functional/17_div.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/functional/53_scope2.sy
#   Compiler Error: testcases/functional/53_scope2.sy
#     Compiler: /home/dh/Compiler/Compiler/MyBackend/RISCVContext.cpp:48: void RISCVContext::extraDealStoreInst(RISCVInst*, StoreInst*): Assertion `allocInst && "must not be nullptr"' failed.
# Processing: testcases/functional/04_arr_defn3.sy
#   Compiler Error: testcases/functional/04_arr_defn3.sy
#
# Processing: testcases/functional/38_op_priority4.sy
#   Compiler Error: testcases/functional/38_op_priority4.sy
#     Compiler: /home/dh/Compiler/Compiler/MyBackend/RISCVContext.cpp:48: void RISCVContext::extraDealStoreInst(RISCVInst*, StoreInst*): Assertion `allocInst && "must not be nullptr"' failed.
# Processing: testcases/functional/99_matrix_tran.sy
#   Compiler Error: testcases/functional/99_matrix_tran.sy
#
# Processing: testcases/functional/06_const_var_defn2.sy
#   Assembler Error: testcases/functional/06_const_var_defn2.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/functional/73_int_io.sy
#   Compiler Error: testcases/functional/73_int_io.sy
#
# Processing: testcases/functional/95_float.sy
#   Compiler Error: testcases/functional/95_float.sy
#
# Processing: testcases/functional/35_op_priority1.sy
#   Assembler Error: testcases/functional/35_op_priority1.sy
#     /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find crt0.o: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lm: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lc: No such file or directory
# /usr/lib/gcc/riscv64-unknown-elf/13.2.0/../../../riscv64-unknown-elf/bin/ld: cannot find -lgloss: No such file or directory
# collect2: error: ld returned 1 exit status
# Processing: testcases/functional/65_color.sy
#   Compiler Error: testcases/functional/65_color.sy
#     terminate called after throwing an instance of 'std::invalid_argument'
#   what():  stoi
# Processing: testcases/functional/57_sort_test3.sy
#   Compiler Error: testcases/functional/57_sort_test3.sy
#
# Processing: testcases/functional/55_sort_test1.sy
#   Compiler Error: testcases/functional/55_sort_test1.sy
#
# Processing: testcases/functional/72_hanoi.sy
#   Compiler Error: testcases/functional/72_hanoi.sy
#
# Processing: testcases/functional/69_expr_eval.sy
#   Compiler Error: testcases/functional/69_expr_eval.sy
#     Compiler: /home/dh/Compiler/Compiler/MyBackend/RISCVContext.cpp:48: void RISCVContext::extraDealStoreInst(RISCVInst*, StoreInst*): Assertion `allocInst && "must not be nullptr"' failed.
# Processing: testcases/functional/64_calculator.sy
#   Compiler Error: testcases/functional/64_calculator.sy
#
# Processing: testcases/functional/47_hex_oct_add.sy
#   Compiler Error: testcases/functional/47_hex_oct_add.sy
#
# Processing: testcases/functional/19_mod.sy
#   Compiler Error: testcases/functional/19_mod.sy
#
# Processing: testcases/functional/97_matrix_sub.sy
#   Compiler Error: testcases/functional/97_matrix_sub.sy
#
# Processing: testcases/functional/78_side_effect.sy
#   Compiler Error: testcases/functional/78_side_effect.sy
#
# Processing: testcases/performance/2024-Z3A-28.sy
#   Compiler Error: testcases/performance/2024-Z3A-28.sy
#     terminate called after throwing an instance of 'std::invalid_argument'
#   what():  stoi
# Processing: testcases/performance/2024-VGH-20.sy
#   Compiler Error: testcases/performance/2024-VGH-20.sy
#     terminate called after throwing an instance of 'std::invalid_argument'
#   what():  stoi
# Processing: testcases/performance/2024-XRB-24.sy
#   Compiler Error: testcases/performance/2024-XRB-24.sy
#
# Processing: testcases/performance/2024-OBF-29.sy
#   Compiler Error: testcases/performance/2024-OBF-29.sy
#
# Processing: testcases/performance/2024-BJV-10.sy
#   Compiler Error: testcases/performance/2024-BJV-10.sy
#
# Processing: testcases/performance/2024-5NG-2.sy
#   Compiler Error: testcases/performance/2024-5NG-2.sy
#     terminate called after throwing an instance of 'std::invalid_argument'
#   what():  stoi
# Processing: testcases/performance/2024-FQX-25.sy
#   Compiler Error: testcases/performance/2024-FQX-25.sy
#
# Processing: testcases/performance/2024-ETJ-33.sy
#   Compiler Error: testcases/performance/2024-ETJ-33.sy
#
# Processing: testcases/performance/2024-QV9-34.sy
#   Compiler Error: testcases/performance/2024-QV9-34.sy
#     Compiler: /home/dh/Compiler/Compiler/MyBackend/RISCVContext.cpp:48: void RISCVContext::extraDealStoreInst(RISCVInst*, StoreInst*): Assertion `allocInst && "must not be nullptr"' failed.
# Processing: testcases/performance/2024-IG5-12.sy
#   Compiler Error: testcases/performance/2024-IG5-12.sy
#
# Processing: testcases/performance/2024-U7W-16.sy
#   Compiler Error: testcases/performance/2024-U7W-16.sy
#
# Processing: testcases/performance/2024-LW8-7.sy
#   Compiler Error: testcases/performance/2024-LW8-7.sy
#
# Processing: testcases/performance/2024-T6G-27.sy
#   Compiler Error: testcases/performance/2024-T6G-27.sy
#     terminate called after throwing an instance of 'std::invalid_argument'
#   what():  stoi
# Processing: testcases/performance/2024-XU5-13.sy
#   Compiler Error: testcases/performance/2024-XU5-13.sy
#
# Processing: testcases/performance/2024-JR2-21.sy
#   Compiler Error: testcases/performance/2024-JR2-21.sy
#
# Processing: testcases/performance/2024-TBR-19.sy
#   Compiler Error: testcases/performance/2024-TBR-19.sy
#
# Processing: testcases/performance/2024-V6O-23.sy
#   Compiler Error: testcases/performance/2024-V6O-23.sy
#
# Processing: testcases/performance/2024-BE3-31.sy
#   Compiler Error: testcases/performance/2024-BE3-31.sy
#
# Processing: testcases/performance/2024-I9Y-15.sy
#   Compiler Error: testcases/performance/2024-I9Y-15.sy
#
# Processing: testcases/performance/2024-PAF-17.sy
#   Compiler Error: testcases/performance/2024-PAF-17.sy
#     terminate called after throwing an instance of 'std::invalid_argument'
#   what():  stoi
# Processing: testcases/performance/2024-K22-4.sy
#   Compiler Error: testcases/performance/2024-K22-4.sy
#
# Processing: testcases/performance/2024-FI8-9.sy
#   Compiler Error: testcases/performance/2024-FI8-9.sy
#
# Processing: testcases/performance/2024-1RK-26.sy
#   Compiler Error: testcases/performance/2024-1RK-26.sy
#
# Processing: testcases/performance/2024-U7D-6.sy
#   Compiler Error: testcases/performance/2024-U7D-6.sy
#
# Processing: testcases/performance/2024-VRT-1.sy
#   Compiler Error: testcases/performance/2024-VRT-1.sy
#
# Processing: testcases/performance/2024-51P-30.sy
#   Compiler Error: testcases/performance/2024-51P-30.sy
#
# Processing: testcases/performance/2024-CH1-5.sy
#   Compiler Error: testcases/performance/2024-CH1-5.sy
#
# Processing: testcases/performance/2024-X7M-3.sy
#   Compiler Error: testcases/performance/2024-X7M-3.sy
#     Compiler: /home/dh/Compiler/Compiler/MyBackend/RISCVContext.cpp:48: void RISCVContext::extraDealStoreInst(RISCVInst*, StoreInst*): Assertion `allocInst && "must not be nullptr"' failed.
# Processing: testcases/performance/2024-AZ7-32.sy
#   Compiler Error: testcases/performance/2024-AZ7-32.sy
#
# Processing: testcases/performance/2024-84M-11.sy
#   Compiler Error: testcases/performance/2024-84M-11.sy
#     terminate called after throwing an instance of 'std::invalid_argument'
#   what():  stoi
# Processing: testcases/performance/2024-PCT-14.sy
#   Compiler Error: testcases/performance/2024-PCT-14.sy
#
# Processing: testcases/performance/2024-Y60-18.sy
#   Compiler Error: testcases/performance/2024-Y60-18.sy
#
# Processing: testcases/performance/2024-5HA-8.sy
#   Compiler Error: testcases/performance/2024-5HA-8.sy
#     Compiler: /home/dh/Compiler/Compiler/MyBackend/RISCVContext.cpp:48: void RISCVContext::extraDealStoreInst(RISCVInst*, StoreInst*): Assertion `allocInst && "must not be nullptr"' failed.
# Processing: testcases/performance/2024-2D0-22.sy
#   Compiler Error: testcases/performance/2024-2D0-22.sy
#
# Processing: testcases/h_performance/2024-PKP-8.sy
#   Compiler Error: testcases/h_performance/2024-PKP-8.sy
#
# Processing: testcases/h_performance/2024-LN4-9.sy
#   Compiler Error: testcases/h_performance/2024-LN4-9.sy
#     terminate called after throwing an instance of 'std::invalid_argument'
#   what():  stoi
# Processing: testcases/h_performance/2024-K0I-17.sy
#   Compiler Error: testcases/h_performance/2024-K0I-17.sy
#
# Processing: testcases/h_performance/2024-NKK-22.sy
#   Compiler Error: testcases/h_performance/2024-NKK-22.sy
#
# Processing: testcases/h_performance/2024-FVJ-15.sy
#   Compiler Error: testcases/h_performance/2024-FVJ-15.sy
#     terminate called after throwing an instance of 'std::invalid_argument'
#   what():  stoi
# Processing: testcases/h_performance/2024-CH6-24.sy
#   Compiler Error: testcases/h_performance/2024-CH6-24.sy
#
# Processing: testcases/h_performance/2024-I4W-2.sy
#   Compiler Error: testcases/h_performance/2024-I4W-2.sy
#
# Processing: testcases/h_performance/2024-BAV-3.sy
#   Compiler Error: testcases/h_performance/2024-BAV-3.sy
#     terminate called after throwing an instance of 'std::invalid_argument'
#   what():  stoi
# Processing: testcases/h_performance/2024-C64-14.sy
#   Compiler Error: testcases/h_performance/2024-C64-14.sy
#
# Processing: testcases/h_performance/2024-0ZE-13.sy
#   Compiler Error: testcases/h_performance/2024-0ZE-13.sy
#
# Processing: testcases/h_performance/2024-NCY-23.sy
#   Compiler Error: testcases/h_performance/2024-NCY-23.sy
#     terminate called after throwing an instance of 'std::invalid_argument'
#   what():  stoi
# Processing: testcases/h_performance/2024-NT1-4.sy
#   Compiler Error: testcases/h_performance/2024-NT1-4.sy
#
# Processing: testcases/h_performance/2024-FAF-19.sy
#   Compiler Error: testcases/h_performance/2024-FAF-19.sy
#
# Processing: testcases/h_performance/2024-931-6.sy
#   Compiler Error: testcases/h_performance/2024-931-6.sy
#
# Processing: testcases/h_performance/2024-MXP-16.sy
#   Compiler Error: testcases/h_performance/2024-MXP-16.sy
#
# Processing: testcases/h_performance/2024-2KM-21.sy
#   Compiler Error: testcases/h_performance/2024-2KM-21.sy
#
# Processing: testcases/h_performance/2024-U03-25.sy
#   Compiler Error: testcases/h_performance/2024-U03-25.sy
#     terminate called after throwing an instance of 'std::invalid_argument'
#   what():  stoi
# Processing: testcases/h_performance/2024-1WO-11.sy
#   Compiler Error: testcases/h_performance/2024-1WO-11.sy
#
# Processing: testcases/h_performance/2024-JVU-10.sy
#   Compiler Error: testcases/h_performance/2024-JVU-10.sy
#
# Processing: testcases/h_performance/2024-VTF-5.sy
#   Compiler Error: testcases/h_performance/2024-VTF-5.sy
#
# Processing: testcases/h_performance/2024-7UJ-12.sy
#   Compiler Error: testcases/h_performance/2024-7UJ-12.sy
#
# Processing: testcases/h_performance/2024-KVV-20.sy
#   Compiler Error: testcases/h_performance/2024-KVV-20.sy
#
# Processing: testcases/h_performance/2024-H17-1.sy
#   Compiler Error: testcases/h_performance/2024-H17-1.sy
#
# Processing: testcases/h_performance/2024-DCV-7.sy
#   Compiler Error: testcases/h_performance/2024-DCV-7.sy
#     terminate called after throwing an instance of 'std::invalid_argument'
#   what():  stoi
# Processing: testcases/h_performance/2024-8NL-18.sy
#   Compiler Error: testcases/h_performance/2024-8NL-18.sy
#
#
# ===== Test Summary =====
# Compiler Error: Total: 199
# Runtime Error: Total: 0
# Timeout Error: Total: 0
# Wrong Answer: Total: 0
# TimeOut Function: 0
# Bad Test: Total: 0
# Accepted: Total: 0
# TOTAL TIME: 0.000 seconds
# ========================
#
# Detailed report saved to: ./output/test_report.log
